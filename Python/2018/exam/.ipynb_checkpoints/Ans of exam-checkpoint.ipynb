# %% [markdown]
# # Instructions:

# %% [markdown]
# There are two notebook files. One for practice and one contains the solutions. In the practice notebook, answer the questions in the same line that says '#Answer here.' This way, you can see the questions' output and continue to work on your answer until you get the right answer.
#
# Enjoy the beauty of Python!

# %% [markdown]
# ### Import neccessary libraries and magic :

# %%
#Answer Here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ### Lookup pd.read_excel . It reads excel files into dataframe. Use this to read 'titanic.xls'. Name the dataframe p1_df make sure you read the excel file not anything else.

# %%
#Answer Here

# %%
passengers_df=pd.read_excel('titanic.xls')

# %% [markdown]
# ### Show the head of the dataframe and then briefly execute "info" and note the number of nans etc. Here is a list of column definitions from dictionary.
# Data Variables
#
# Describes the variables in the test / train .csv files. This data dictionary and subsequent info was obtained from Kaggle.
# Variable 	Description 	Details
#
# survival Survival       	0 = No; 1 = Yes
#
# pclass 	Passenger Class 	1 = 1st; 2 = 2nd; 3 = 3rd
#
# name 	First and Last Name
# sex 	Sex
# age 	Age
# sibsp 	Number of Siblings/Spouses Aboard
# parch 	Number of Parents/Children Aboard
# ticket 	Ticket Number
# fare 	Passenger Fare
# cabin 	Cabin
# embarked 	Port of Embarkation 	C = Cherbourg; Q = Queenstown; S = Southampton
#
# SPECIAL NOTES:
#
# PClass can be a proxy for socio-economic status (SES)
#
#     1st ~ Upper;
#     2nd ~ Middle;
#     3rd ~ Lower
#
# Age is in Years; - Fractional if Age less than One (1) - If the Age is Estimated, it is in the form xx.5
#
# With respect to the family relation variables (i.e. sibsp and parch) some relations were ignored. The following are the definitions used for sibsp and parch.
#
# Sibling: Brother, Sister, Stepbrother, or Stepsister of Passenger Aboard Titanic Spouse: Husband or Wife of Passenger Aboard Titanic (Mistresses and Fiances Ignored) Parent: Mother or Father of Passenger Aboard Titanic Child: Son, Daughter, Stepson, or Stepdaughter of Passenger Aboard Titanic
#
# Other family relatives excluded from this study include cousins, nephews/nieces, aunts/uncles, and in-laws. Some children travelled only with a nanny, therefore parch=0 for them. As well, some travelled with very close friends or neighbors in a village, however, the definitions do not support such relations.

# %%
#execute head(5)
#Answer Here

# %%
passengers_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### Describe some stats on the data and briefly explain what the categories mean like how many Nans there are and which columns

# %%
#Answer here
passengers_df.info()

# tell you data type, rows, columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 14 columns):
# pclass       1301 non-null int64
# survived     1301 non-null int64
# name         1301 non-null object
# sex          1301 non-null object
# age          1040 non-null float64
# sibsp        1301 non-null int64
# parch        1301 non-null int64
# ticket       1300 non-null object
# fare         1300 non-null float64
# cabin        295 non-null object
# embarked     1299 non-null object
# boat         486 non-null object
# body         118 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 142.4+ KB

# %% [markdown]
# ### 'Describe' the main statistical features of the data. What is the median value mean? Pick a column and explain.

# %%
#Answer here

# %%
passengers_df.describe(include='all')
# Out:
#              pclass     survived              name   sex          age  \
# count   1301.000000  1301.000000              1301  1301  1040.000000
# unique          NaN          NaN              1299     2          NaN
# top             NaN          NaN  Kelly, Mr. James  male          NaN
# freq            NaN          NaN                 2   837          NaN
# mean       2.290546     0.384320               NaN   NaN    29.902083
# std        0.838577     0.486621               NaN   NaN    14.430969
# min        1.000000     0.000000               NaN   NaN     0.166700
# 25%        2.000000     0.000000               NaN   NaN    21.000000
# 50%        3.000000     0.000000               NaN   NaN    28.000000
# 75%        3.000000     1.000000               NaN   NaN    39.000000
# max        3.000000     1.000000               NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %% [markdown]
# ### Include 50% to 100% percentile with 5% increments for the 'age' column in the describe method output

# %%
#Answer here
passengers_df.age.describe(percentiles=np.arange(.5,1,0.05))
# Out:
# count    1040.000000
# mean       29.902083
# std        14.430969
# min         0.166700
# 50%        28.000000
# 55.0%      30.000000
# 60.0%      31.000000
# 65.0%      33.000000
# 70.0%      36.000000
# 75.0%      39.000000
# 80.0%      42.000000
# 85.0%      45.000000
# 90.0%      50.000000
# 95.0%      57.000000
# max        80.000000
# Name: age, dtype: float64

# %%
type(passengers_df.age.describe(percentiles=np.arange(.5,1,0.05)))
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### What is the 80% percentile of the 'age' column?

# %%
#Answer here
passengers_df.age.describe(percentiles=np.arange(.5,1,0.05))['80.0%']
# Out:
# 42.0

# %% [markdown]
# ### Create a sub dataframe where the age of passengers is above the 80% percentile calculated above

# %%
#Answer here

# %%
passengers_df.age.describe(percentiles=np.arange(.5,1,0.05))['80.0%':]
# Out:
# 80.0%    42.0
# 85.0%    45.0
# 90.0%    50.0
# 95.0%    57.0
# max      80.0
# Name: age, dtype: float64

# %%
passengers_df.age.describe(percentiles=np.arange(.5,1,0.05))[-1]
# Out:
# 80.0

# %% [markdown]
# ### Count the number of passengers in first class

# %%
#Answer here
passengers_df[passengers_df['pclass']==1]['pclass'].count()
# Out:
# 323

# %% [markdown]
# ### Create a new column called 'older than 90% percentile' where it's true/false if the passenger is older/younger than the 90% percentile

# %%
#Answer here
passengers_df['older_than_90%_percentile']= passengers_df['age']>50.0
passengers_df['older_than_90%_percentile'].sum()
# Out:
# 95

# %%
passengers_df[passengers_df['older_than_90%_percentile']==True]['older_than_90%_percentile'].count()
# Out:
# 95

# %%
passengers_df[passengers_df['older_than_90%_percentile'].isnull()]['older_than_90%_percentile'].count()
# Out:
# 0

# %% [markdown]
# ### Group the 'fare' column by the class of passenger and get the mean fare price for each class

# %%
#Answer here
fare_group=passengers_df.groupby(by='pclass')['fare'].agg(['mean', 'std', 'median', 'min', 'max'])
fare_group
# Out:
#              mean        std   median  min       max
# pclass
# 1       87.508992  80.447178  60.0000  0.0  512.3292
# 2       21.179196  13.607122  15.0458  0.0   73.5000
# 3       13.319785  11.559590   8.0500  0.0   69.5500

# %% [markdown]
# ### Plot the bar chart for the avg fare grouped by class

# %%
#Answer here
fare_group.plot(kind='bar')

# preliminary bin = (max-min)/total number

# %%
fare_group.plot(kind='bar')

# %% [markdown]
# ### Getting the number of outliers: define the upper bound and lower bound for the 'fare' column at 95% and 5% and count how many passengers are considered outliers

# %%
#Answer here
five_pct=passengers_df.fare.describe(percentiles=np.arange(.05,1,0.05))['5%']
ninety_five_pct=passengers_df.fare.describe(percentiles=np.arange(.05,1,0.05))['95%']

# %%
five_pct
# Out:
# 7.2249999999999996

# %%
passengers_df[passengers_df['fare']<=five_pct]['fare'].value_counts()
# Out:
# 0.0000    18
# 7.2250    17
# 7.0500     9
# 7.1250     4
# 6.4958     3
# 6.4375     3
# 7.0000     2
# 6.9750     2
# 6.7500     2
# 6.9500     2
# 7.0542     2
# 5.0000     1
# 7.1417     1
# 7.0458     1
# 6.2375     1
# 6.4500     1
# 3.1708     1
# 6.8583     1
# 4.0125     1
# Name: fare, dtype: int64

# %%
passengers_df[passengers_df['fare']<=five_pct]['fare'].value_counts().sum()
# Out:
# 72

# %%
passengers_df[passengers_df['fare']<=five_pct]['fare'].count()
# Out:
# 72

# %%
passengers_df[passengers_df['fare']>=ninety_five_pct]['fare'].count() #用这个方法数
# Out:
# 65

# %%
passengers_df[passengers_df['fare']>=ninety_five_pct]['fare']
# Out:
# 0      211.3375
# 1      151.5500
# 2      151.5500
# 3      151.5500
# 4      151.5500
# 10     227.5250
# 11     227.5250
# 16     247.5208
# 17     247.5208
# 23     227.5250
# 24     221.7792
# 28     135.6333
# 32     164.8667
# 35     262.3750
# 44     134.5000
# 49     512.3292
# 50     512.3292
# 66     262.3750
# 71     136.7792
# 72     136.7792
# 73     151.5500
# 88     151.5500
# 97     247.5208
# 103    227.5250
# 106    221.7792
# 111    263.0000
# 112    263.0000
# 113    263.0000
# 114    263.0000
# 115    263.0000
#          ...
# 180    211.3375
# 183    512.3292
# 192    146.5208
# 193    211.3375
# 236    135.6333
# 237    227.5250
# 238    211.3375
# 249    262.3750
# 250    262.3750
# 251    262.3750
# 252    262.3750
# 253    262.3750
# 260    153.4625
# 273    134.5000
# 274    134.5000
# 275    134.5000
# 276    146.5208
# 277    146.5208
# 285    221.7792
# 286    221.7792
# 302    512.3292
# 308    135.6333
# 309    164.8667
# 310    164.8667
# ...

# %%
type(passengers_df['fare']>=ninety_five_pct)
# Out:
# pandas.core.series.Series

# %%
passengers_df[passengers_df['fare']>=ninety_five_pct]['sex'].count()
# Out:
# 65

# %%
passengers_df[passengers_df['fare']>=ninety_five_pct].count()
# Out:
# pclass       65
# survived     65
# name         65
# sex          65
# age          62
# sibsp        65
# parch        65
# ticket       65
# fare         65
# cabin        55
# embarked     65
# boat         44
# body          6
# home.dest    48
# dtype: int64

# %%
passengers_df[passengers_df['fare']>=ninety_five_pct]['fare'].value_counts().sum()
# Out:
# 65

# %% [markdown]
# ### Replace outliers ( all values less than 5 % and greater then 95% above) in the dataframe by the mean of the 'fare' column You may wish to copy() the dataframe before doing so into another dataframe.

# %%
passengers_df['fare'].mean()
# Out:
# 33.42760846153862

# %%
#Answer here passengers_df['fare'][(passengers_df['fare'] > upper_bound) | (passengers_df['fare'] < lower_bound)] = passengers_df['fare'].mean()

p_df2=passengers_df.copy()
p_df2.head()
p_df2.loc[p_df2['fare'] < five_pct,'fare']=33.42 # assign any 'fare' with < 5% to be 33.42
# p_df2[p_df2.loc[:,'fare']<five_pct]['fare']=p_df2['fare'].mean()

# %%
p_df2[p_df2.loc[:,'fare']==33.42].head()
# Out:
#      pclass  survived                                   name   sex   age  \
# 7         1         0                 Andrews, Mr. Thomas Jr  male  39.0
# 51        1         0               Carlsson, Mr. Frans Olof  male  33.0
# 70        1         0  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 125       1         0                       Fry, Mr. Richard  male   NaN
# 150       1         0                  Harrison, Mr. William  male  40.0
#
#      sibsp  parch  ticket   fare        cabin embarked boat   body  \
# 7        0      0  112050  33.42          A36        S  NaN    NaN
# 51       0      0     695  33.42  B51 B53 B55        S  NaN    NaN
# 70       0      0  112051  33.42          NaN        S  NaN    NaN
# 125      0      0  112058  33.42         B102        S  NaN    NaN
# 150      0      0  112059  33.42          B94        S  NaN  110.0
#
#                         home.dest  older_than_90%_percentile
# 7                     Belfast, NI                      False
# ...

# %%
#> ninety_five_pct
p_df2.loc[p_df2['fare'] > ninety_five_pct,'fare']=33.42

# %%
ninety_five_pct
# Out:
# 133.69249999999997

# %%
p_df2.loc[p_df2.loc[:,'fare']==33.42,['fare']].head()
# Out:
#     fare
# 0  33.42
# 1  33.42
# 2  33.42
# 3  33.42
# 4  33.42

# %% [markdown]
# ### Load the contents of 'titanic2.csv', name it df2.
# ### Look at the head of the data for its structure and combine it with the previous dataframe

# %%
#Answer here
df2=pd.read_csv('titanic2.csv')
df2.head()
# Out:
#    pclass  survived                                     name     sex   age  \
# 0       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1       3         0                     Youseff, Mr. Gerious    male  45.5
# 2       3         0                        Yousif, Mr. Wazli    male   NaN
# 3       3         0                    Yousseff, Mr. Gerious    male   NaN
# 4       3         0                     Zabour, Miss. Hileni  female  14.5
#
#    sibsp  parch  ticket     fare  cabin embarked  boat   body  home.dest
# 0      1      0    2659  14.4542    NaN        C   NaN    NaN        NaN
# 1      0      0    2628   7.2250    NaN        C   NaN  312.0        NaN
# 2      0      0    2647   7.2250    NaN        C   NaN    NaN        NaN
# 3      0      0    2627  14.4583    NaN        C   NaN    NaN        NaN
# 4      1      0    2665  14.4542    NaN        C   NaN  328.0        NaN

# %%
#Anaswer here
combodf=pd.concat([passengers_df,df2],ignore_index='True')
combodf
# Out:
#           age boat   body    cabin embarked      fare  \
# 0     29.0000    2    NaN       B5        S  211.3375
# 1      0.9167   11    NaN  C22 C26        S  151.5500
# 2      2.0000  NaN    NaN  C22 C26        S  151.5500
# 3     30.0000  NaN  135.0  C22 C26        S  151.5500
# 4     25.0000  NaN    NaN  C22 C26        S  151.5500
# 5     48.0000    3    NaN      E12        S   26.5500
# 6     63.0000   10    NaN       D7        S   77.9583
# 7     39.0000  NaN    NaN      A36        S    0.0000
# 8     53.0000    D    NaN     C101        S   51.4792
# 9     71.0000  NaN   22.0      NaN        C   49.5042
# 10    47.0000  NaN  124.0  C62 C64        C  227.5250
# 11    18.0000    4    NaN  C62 C64        C  227.5250
# 12    24.0000    9    NaN      B35        C   69.3000
# 13    26.0000    6    NaN      NaN        S   78.8500
# 14    80.0000    B    NaN      A23        S   30.0000
# 15        NaN  NaN    NaN      NaN        S   25.9250
# ...

# %% [markdown]
# ### How many rows does df2 have ?

# %%
#Ans
combodf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 15 columns):
# age                          1046 non-null float64
# boat                         486 non-null object
# body                         121 non-null float64
# cabin                        295 non-null object
# embarked                     1308 non-null object
# fare                         1309 non-null float64
# home.dest                    745 non-null object
# name                         1310 non-null object
# older_than_90%_percentile    1301 non-null object
# parch                        1310 non-null int64
# pclass                       1310 non-null int64
# sex                          1310 non-null object
# sibsp                        1310 non-null int64
# survived                     1310 non-null int64
# ticket                       1309 non-null object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 153.6+ KB

# %% [markdown]
# ### Plot a scatter plot of 'age' vs 'fare' for your data and calculate the correlation between these two columns

# %%
#Answer here

# %%
combodf[['fare','age']].corr()
# Out:
#           fare       age
# fare  1.000000  0.178739
# age   0.178739  1.000000

# %%
x=combodf['age']
y=combodf['fare']

# %%
plt.scatter(x,y)

# %% [markdown]
# ### Drop 'name', 'cabin', 'boat', 'body','home.dest', 'embarked', 'ticket' columns

# %%
#Answer here

# %%
combodf.drop(['cabin','boat','body','home.dest','embarked','ticket'],\
             axis=1,inplace=True) # modify the dataset
combodf
# Out:
#           age      fare                                               name  \
# 0     29.0000  211.3375                      Allen, Miss. Elisabeth Walton
# 1      0.9167  151.5500                     Allison, Master. Hudson Trevor
# 2      2.0000  151.5500                       Allison, Miss. Helen Loraine
# 3     30.0000  151.5500               Allison, Mr. Hudson Joshua Creighton
# 4     25.0000  151.5500    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5     48.0000   26.5500                                Anderson, Mr. Harry
# 6     63.0000   77.9583                  Andrews, Miss. Kornelia Theodosia
# 7     39.0000    0.0000                             Andrews, Mr. Thomas Jr
# 8     53.0000   51.4792      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9     71.0000   49.5042                            Artagaveytia, Mr. Ramon
# 10    47.0000  227.5250                             Astor, Col. John Jacob
# ...

# %% [markdown]
# # Filling missing data in 'age' column by using an educated guess:

# %% [markdown]
# ### Write a function that takes two columns, 'age' and 'pclass', as input and depending on which pclass, if the age is NaN (command: pd.isnull(age)   ) it returns age 40, 30 or 25. For example, if input is [NaN, 1], it returns age = 40

# %%
#Answer here

# %%
def handle_nan_age(cols):
    age = cols[0]
    pclass = cols[1]
    if pd.isnull(age):
        if pclass == 1:
            age = 40
        elif pclass == 2:
            age = 30
        else:
            age = 25
    return age

# %% [markdown]
# ### Use apply to clean up age database for NaN using the function created above

# %%
#Answer here
passengers_df[['age']]=passengers_df[['age','pclass']].apply(handle_nan_age,axis=1)

# %%
passengers_df.isnull() # output是true和false的二维表格

# %%
passengers_df.isnull().sum()
# Out:
# pclass                          0
# survived                        0
# name                            0
# sex                             0
# age                           261
# sibsp                           0
# parch                           0
# ticket                          1
# fare                            1
# cabin                        1006
# embarked                        2
# boat                          815
# body                         1183
# home.dest                     556
# older_than_90%_percentile       0
# dtype: int64

# %%
passengers_df.isnull().count()
# Out:
# pclass                       1301
# survived                     1301
# name                         1301
# sex                          1301
# age                          1301
# sibsp                        1301
# parch                        1301
# ticket                       1301
# fare                         1301
# cabin                        1301
# embarked                     1301
# boat                         1301
# body                         1301
# home.dest                    1301
# older_than_90%_percentile    1301
# dtype: int64

# %%
passengers_df.fare.isnull()

# %% [markdown]
# ### In the 'fare' column, isolate and display the row where there is NaN

# %%
#Answer here
passengers_df[passengers_df.fare.isnull()]
# passengers_df.fare.isnull() 是一个true和false组成的series
# Out:
#       pclass  survived                name   sex   age  sibsp  parch ticket  \
# 1226       3         0  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#       fare cabin embarked boat   body home.dest  older_than_90%_percentile
# 1226   NaN   NaN        S  NaN  261.0       NaN                       True

# %%
type(passengers_df[passengers_df.fare.isnull()]) # 扔进去series，返回一个dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
type(passengers_df['age']) # 扔进去字符串，返回这一列的series
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Using apply fuction, convert the data in 'sex' column to zeros and ones: if female, replace by 1, otherwise by 0

# %%
#Answer here
def convert_sex(sex):
    return(1 if sex == 'male' else 2)

# %%
passengers_df['sex']=passengers_df['sex'].apply(convert_sex) # apply itself doesn't inplace the orginal data

# %% [markdown]
# ### Display the top rows for 'sex' column

# %%
#Answer here
passengers_df['sex']
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       2
# 5       1
# 6       2
# 7       1
# 8       2
# 9       1
# 10      1
# 11      2
# 12      2
# 13      2
# 14      1
# 15      1
# 16      1
# 17      2
# 18      2
# 19      1
# 20      1
# 21      2
# 22      1
# 23      2
# 24      2
# 25      1
# 26      1
# 27      2
# 28      2
# 29      1
#        ..
# 1271    1
# 1272    1
# 1273    1
# 1274    2
# 1275    1
# 1276    1
# 1277    2
# 1278    1
# 1279    1
# 1280    2
# 1281    1
# 1282    1
# 1283    1
# 1284    1
# 1285    1
# 1286    1
# 1287    2
# 1288    1
# 1289    1
# 1290    1
# 1291    2
# 1292    1
# 1293    1
# 1294    1
# 1295    1
# 1296    1
# 1297    1
# 1298    1
# 1299    1
# 1300    1
# Name: sex, Length: 1301, dtype: int64

# %% [markdown]
# ### Confirm that the contents of the 'sex' column are integers by showing the type of one content (zero's index, first, etc) or using the info command

# %%
#Answer here

# %%
passengers_df.sex.values
# Out:
# array([2, 1, 2, ..., 1, 1, 1])

# %%
passengers_df.sex.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### In 'fare' column, replace NaN with the mean of the column

# %%
#Answer here
m=passengers_df['fare'].mean()
m
# Out:
# 33.42760846153862

# %%
passengers_df.loc[passengers_df.loc[:,'fare'].isnull(),['fare']]
# Out:
#       fare
# 1226   NaN

# %%
passengers_df.loc[passengers_df.loc[:,'fare'].isnull(),['fare', 'sex']]
# Out:
#       fare   sex
# 1226   NaN  male

# %%
passengers_df.loc[:,['fare']].head()
# Out:
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500

# %%
# passengers_df.loc[passengers_df.loc[:,['fare']].isnull(),['fare']]
passengers_df.loc[:,['fare']].isnull()
# Out:
#        fare
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# ...     ...
# 1271  False
# 1272  False
# 1273  False
# 1274  False
# 1275  False
# 1276  False
# 1277  False
# 1278  False
# 1279  False
# 1280  False
# 1281  False
# 1282  False
# 1283  False
# 1284  False
# 1285  False
# 1286  False
# 1287  False
# 1288  False
# 1289  False
# 1290  False
# 1291  False
# 1292  False
# 1293  False
# 1294  False
# 1295  False
# 1296  False
# 1297  False
# 1298  False
# 1299  False
# 1300  False
#
# [1301 rows x 1 columns]

# %%
passengers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 15 columns):
# pclass                       1301 non-null int64
# survived                     1301 non-null int64
# name                         1301 non-null object
# sex                          1301 non-null int64
# age                          1301 non-null float64
# sibsp                        1301 non-null int64
# parch                        1301 non-null int64
# ticket                       1300 non-null object
# fare                         1300 non-null float64
# cabin                        295 non-null object
# embarked                     1299 non-null object
# boat                         486 non-null object
# body                         118 non-null float64
# home.dest                    745 non-null object
# older_than_90%_percentile    1301 non-null bool
# dtypes: bool(1), float64(3), int64(5), object(6)
# memory usage: 143.6+ KB

# %% [markdown]
# ### Drop any leftover NaN in the dataframe

# %%
#Answer here

# %%
passengers_df.info() # use info to check non-null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 15 columns):
# pclass                       1301 non-null int64
# survived                     1301 non-null int64
# name                         1301 non-null object
# sex                          1301 non-null int64
# age                          1301 non-null float64
# sibsp                        1301 non-null int64
# parch                        1301 non-null int64
# ticket                       1300 non-null object
# fare                         1300 non-null float64
# cabin                        295 non-null object
# embarked                     1299 non-null object
# boat                         486 non-null object
# body                         118 non-null float64
# home.dest                    745 non-null object
# older_than_90%_percentile    1301 non-null bool
# dtypes: bool(1), float64(3), int64(5), object(6)
# memory usage: 143.6+ KB

# %% [markdown]
# ### Display the head of cleaned dataframe

# %%
#Answer here

# %% [markdown]
# # Merge and Concat Practice:

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                        'B': ['B0', 'B1', 'B2'],
                        'C': ['C0', 'C1', 'C2'],
                        'D': ['D0', 'D1', 'D2']},
                        index=[0, 1, 2])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6'],
                        'B': ['B4', 'B5', 'B6'],
                        'C': ['C4', 'C5', 'C6'],
                        'D': ['D4', 'D5', 'D6']},
                         index=[0, 1, 2])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10'],
                        'B': ['B8', 'B9', 'B10'],
                        'C': ['C8', 'C9', 'C10'],
                        'E': ['D8', 'D9', 'D10']},
                        index=[0, 1, 2])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6

# %% [markdown]
# ### Concat the dataframes above

# %%
#Answer here

# %%
pd.concat([df1,df2,df3], ignore_index=True)
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A4   B4   C4   D4
# 4   A5   B5   C5   D5
# 5   A6   B6   C6   D6
# 6   A8   B8   C8   D8
# 7   A9   B9   C9   D9
# 8  A10  B10  C10  D10

# %% [markdown]
# ### Concat the three dataframes on columns

# %%
#Answer here

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#     A   B   C   D  k   A   B   C   D  k    A    B    C    D
# 0  A0  B0  C0  D0  a  A4  B4  C4  D4  a   A8   B8   C8   D8
# 1  A1  B1  C1  D1  b  A5  B5  C5  D5  b   A9   B9   C9   D9
# 2  A2  B2  C2  D2  c  A6  B6  C6  D6  c  A10  B10  C10  D10

# %% [markdown]
# ### Add 'key' column to both df1 and df2 as ['a','b','c'] and merge df1 and df2 on the shared key

# %%
#Answer here

# %%
df1=df1.assign(k=['a','b','c']) # create a new column and assign value.

# %%
df1
# Out:
#     A   B   C   D  k
# 0  A0  B0  C0  D0  a
# 1  A1  B1  C1  D1  b
# 2  A2  B2  C2  D2  c

# %%
df2=df2.assign(k=['a','b','c'])
df2
# Out:
#     A   B   C   D  k
# 0  A4  B4  C4  D4  a
# 1  A5  B5  C5  D5  b
# 2  A6  B6  C6  D6  c

# %%
pd.merge(df1,df2,on='k')
# Out:
#   A_x B_x C_x D_x  k A_y B_y C_y D_y
# 0  A0  B0  C0  D0  a  A4  B4  C4  D4
# 1  A1  B1  C1  D1  b  A5  B5  C5  D5
# 2  A2  B2  C2  D2  c  A6  B6  C6  D6

# %%
df3=df3.assign(k=['a','b','d'])
df3
# Out:
#      A    B    C    E  k
# 0   A8   B8   C8   D8  a
# 1   A9   B9   C9   D9  b
# 2  A10  B10  C10  D10  d

# %%
#left key =d is absnet from df2 
pd.merge(df2,df3, on='k',how='left')
# Out:
#   A_x B_x C_x   D  k  A_y  B_y  C_y    E
# 0  A4  B4  C4  D4  a   A8   B8   C8   D8
# 1  A5  B5  C5  D5  b   A9   B9   C9   D9
# 2  A6  B6  C6  D6  c  NaN  NaN  NaN  NaN

# %% [markdown]
# ### Concat df1 and df3 (pay attention to the NaN data)

# %%
#Answer here

# %%
pd.concat([df1,df3],join='outer')
# Out:
#      A    B    C    D    k
# 0   A0   B0   C0   D0    a
# 1   A1   B1   C1   D1    b
# 2   A2   B2   C2   D2    c
# 0   A8   B8   C8   D8  NaN
# 1   A9   B9   C9   D9  NaN
# 2  A10  B10  C10  D10  NaN

# %% [markdown]
# # Extra data analysis examples:
# #### Although the final answer is mostly one line, the process and the final answer can be broken down into several lines.

# %% [markdown]
# ### Load the dataframe in 'http://www.fdic.gov/bank/individual/failed/banklist.html'. The result is a list and its zero index is the dataframe we want. Display the head of the data, info, and describe and explain the structure of the data briefly.

# %%
#Answer here
dfxx=pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
#Answer here
dfxy=dfxx[0]
dfxy.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  February 21, 2018
# 1                          Conway Bank   October 13, 2017  February 21, 2018
# 2            United Fidelity Bank, fsb       May 26, 2017      July 26, 2017
# 3  First-Citizens Bank & Trust Company        May 5, 2017     March 22, 2018
# 4                         Whitney Bank     April 28, 2017   December 5, 2017

# %%
#Answer here
dfxy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
# Bank Name                555 non-null object
# City                     555 non-null object
# ST                       555 non-null object
# CERT                     555 non-null int64
# Acquiring Institution    555 non-null object
# Closing Date             555 non-null object
# Updated Date             555 non-null object
# dtypes: int64(1), object(6)
# memory usage: 30.4+ KB

# %%
#Answer here

# %%
dfxy.describe(include='all')
# Out:
#                Bank Name     City   ST          CERT Acquiring Institution  \
# count                555      555  555    555.000000                   555
# unique               539      426   44           NaN                   290
# top     First State Bank  Chicago   GA           NaN           No Acquirer
# freq                   3       20   93           NaN                    31
# mean                 NaN      NaN  NaN  31702.318919                   NaN
# std                  NaN      NaN  NaN  16401.784351                   NaN
# min                  NaN      NaN  NaN     91.000000                   NaN
# 25%                  NaN      NaN  NaN  20315.000000                   NaN
# 50%                  NaN      NaN  NaN  32185.000000                   NaN
# 75%                  NaN      NaN  NaN  35364.000000                   NaN
# max                  NaN      NaN  NaN  58701.000000                   NaN
#
#             Closing Date    Updated Date
# ...

# %% [markdown]
# ### What are the top 3 acquiring institutions?

# %%
#Answer here
#Acquiring institutions

dfxy['Acquiring Institution'].value_counts().iloc[:3] # iloc is for index, loc is for label
# Out:
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Name: Acquiring Institution, dtype: int64

# %%
dfxy['Acquiring Institution'].value_counts().loc[:3] - 会报错

# %% [markdown]
# ### How many city names start with the letter 'A'  and how many don't?

# %%
#Answer here

# %%
dfxy['City'].apply(lambda x: x[0].startswith('A')).value_counts()
#dfxy['City'].apply(lambda name:name[0].upper() =='A').value_counts()
# Out:
# False    521
# True      34
# Name: City, dtype: int64

# %%
dfxy['City'].apply(lambda x: x[0].startswith('A'))
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 525    False
# 526    False
# 527    False
# 528    False
# 529     True
# 530    False
# 531    False
# 532    False
# 533    False
# 534    False
# 535    False
# 536    False
# 537    False
# 538    False
# 539     True
# 540     True
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# Name: City, Length: 555, dtype: bool

# %% [markdown]
# ### What are the cities whose names consist of 2 words and how many are there?

# %%
#Answer here
dfxy[dfxy['City'].apply(lambda name: len(name.split())==2)]

# %%
sum(dfxy['City'].apply(lambda name: len(name.split())==2))

# %% [markdown]
# # QED!
